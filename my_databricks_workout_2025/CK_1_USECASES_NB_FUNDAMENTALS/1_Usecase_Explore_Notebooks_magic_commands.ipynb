# %% [markdown]
# ######Task1: Document the Notebook Using mark down %md <br>
# A good Title <br>
# Description of the task <br>
# Your name in some color <br>
# Bring our Team photo from the given url "https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg" <br>
# Use headings, bold, italics appropriately. <br>
#
# Task2: Create a volume namely usage_metrics using sql magic command %sql
#
# Task3:
# Create a child notebook "4_child_nb_dataload" and write code to load data, Using the requests library, perform api call to pull data from "https://public.tableau.com/app/sample-data/mobile_os_usage.csv" into a python variable using the magic command %py and write the data into the created volume "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv" using the above variable.text using the magic command dbutils.fs.put("volume",variable.text,overwrite=True)
#
# Task4: Call the notebook 4_child_nb_dataload using the magic command %run
#
# Task5: list the file is created in the given volume or not and do the head of this file using fs magic command %fs
#
# Task6: Create a pyspark dataframe df1 reading the data from the above file using pyspark magic command %python
#
# Task7: Write the above dataframe df1 data into a databricks table called 'default.mobile_os_usage' using pyspark magic command %python
#
# Task8: Write sql query to display the data loaded into the table 'default.mobile_os_usage' using the pyspark magic command %python
#
# Task9: Create a python function to convert the given input to upper case
#
# Task10: Install pandas library using the pip python magic command %pip
#
# Task11: Import pandas, using pandas read_csv and display the output using the magic command %python
#
# Task12: echo "Magic commands tasks completed" using the linux shell magic command %sh

# %% [markdown]
# #Task 1

# %% [markdown]
# #Notebook Fundamentels
# ## Your name in some color
# Name: <span style="color:red">Chenthil</span>
# <br/><br/>
# Bring our Team photo from the given url
# ![TeamPhoto](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)
#
# Use headings, **bold**, *italics* appropriately.

# %% [markdown]
# This is normal text.  <br>
# <span style="color:red">This text is red.</span>  <br>
# <span style="color:#0000FF">This text is blue using a hex code.</span> <br>
#
#
#
#
# This is <span style="background-color: #FFFF00">highlighted</span> <br>
# This is <span style="color:red">red</span><br>
#
# <br>
# This is <font  color='red'> red </font> <br>
# <mark  style="background-color: lightblue">higlight</mark>

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
#
# **This is bold**
#
# *This is italicized*
#
# ~~This is a strikethrough~~
#
# > This is a blockquote
#
# `This is an inline code`
#
# `` `This escapes backtick` ``
#
# ```
# This
# is
# a
# code
# blcok
# ```
#
# [GrabNGoInfo](https://grabngoinfo.com/)
# <br>
# [markdown cheatbook](https://databricks-prod-cloudfront.cloud.databricks.com/public/4027ec902e239c93eaaa8714f173bcfc/1395231203492935/2328178954927609/4227492383157538/latest.html)
# ---
#
# This is <span style="background-color: #FFFF00">highlighted</span>
#
# This is <span style="color:red">red</span>
#
# Line above space <br/><br/> Line below space
#
# GrabNGoInfo is awesome! ❤️
#
# \\(A{_i}{_j}\\)
#
# \\(A{^i}{^j}\\)
#
# | Column 1 | Column 2 |
# | ----------- | ----------- |
# | Row 1 | Value 1 |
# | Row 2 | Value 2 |

# %% [markdown]
# #Task2:
# Create a volume namely usage_metrics using sql magic command %sql

# %%
# %sql
-- DROP VOLUME IF EXISTS workspace.default.usage_metrics` RECURSIVE
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics

# %%
# %sh ls -ls "/Volumes/workspace/default/"

# %% [markdown]
# #Task3:
# Create a child notebook "4_child_nb_dataload" and write code to load data, Using the requests library, perform api call to pull data from "https://public.tableau.com/app/sample-data/mobile_os_usage.csv" into a python variable using the magic command %py and write the data into the created volume "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv" using the above variable.text using the magic command dbutils.fs.put("volume",variable.text,overwrite=True)
#
# ## child_np_use_case

# %% [markdown]
# #Task4:
# Call the notebook 4_child_nb_dataload using the magic command %run

# %%
# %run "/Workspace/Users/chen.learning.resources@gmail.com/databricks-code-repo-public_chenthil/my_databricks_workout_2025/CK_1_USECASES_NB_FUNDAMENTALS/child_nb_use_case"

# %% [markdown]
# #Task5:
# list the file is created in the given volume or not and do the head of this file using fs magic command %fs

# %%
# %fs ls "/Volumes/workspace/default/usage_metrics/"

# %%
# %fs head "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"

# %% [markdown]
# #Task6:
# Create a pyspark dataframe df1 reading the data from the above file using pyspark magic command %python

# %%
# %python
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
df1.show()

# %% [markdown]
# #Task7:
# Write the above dataframe df1 data into a databricks table called 'default.mobile_os_usage' using pyspark magic command %python

# %%
# %python
df1.write.saveAsTable("default.mobile_os_usage1")

# %% [markdown]
# #Task8:
# Write sql query to display the data loaded into the table 'default.mobile_os_usage' using the pyspark magic command %python

# %%
# %sql
select * from mobile_os_usage1

# %% [markdown]
# #Task9:
# Create a python function to convert the given input to upper case

# %%
# %python
text="lower_case_to_uppercase"
print(text.upper())

# %% [markdown]
# #Task10:
# Install pandas library using the pip python magic command %pip

# %%
# %pip install pandas

# %% [markdown]
# #Task11:
# Import pandas, using pandas read_csv and display the output using the magic command %python

# %%
# %python
import pandas as pd
path="/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"
df2 = pd.read_csv(path)
display(df2)

# %% [markdown]
# #Task12:
# echo "Magic commands tasks completed" using the linux shell magic command %sh

# %%
# %sh
echo "Magic commands tasks completed"
