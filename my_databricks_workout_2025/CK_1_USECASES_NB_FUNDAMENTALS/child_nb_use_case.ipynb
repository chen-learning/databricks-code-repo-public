# %%
# %py
import requests

url_path ="https://public.tableau.com/app/sample-data/mobile_os_usage.csv"
variable = requests.get(url_path)
print(variable.text)

dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", variable.text, True)

# %%
# %fs ls /Volumes/workspace/default/usage_metrics/

# %%
# %py
dbutils.notebook.exit(0)
