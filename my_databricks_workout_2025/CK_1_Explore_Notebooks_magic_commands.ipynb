# %% [markdown]
# #My First NoteBook

# %% [markdown]
# ##1. Exploring Magic Command
# ##2. Markdown design in notebook
# ##3. Widgets
# ##4. dbutils (db utilities)

# %% [markdown]
# ###Explore Magic commands

# %%
# %lsmagic

# %% [markdown]
# ###%md magic command - for markdowns

# %% [markdown]
# ####Important Magic Commands
# - %md: allows you to write markdown text to design the notebook.
# - %run: runs a Python file or a notebook.
# - %sh: executes shell commands on the cluster edge/client node.
# - %fs: allows you to interact with the Databricks file system (Datalake command (cloud storage s3/adls/gcs))
# - %sql: allows you to run Spark SQL/HQL queries.
# - %python: switches the notebook context to Python.
# - %pip: allows you to install Python packages.
#
# ####Not Important Magic Commands or We learn few of these where we have Cloud(Azure) dependency
# - %scala: switches the notebook context to Scala.
# - %r: switches the notebook context to R.
# - %lsmagic: lists all the available magic commands.
# - %config: allows you to set configuration options for the notebook.
# - %load: loads the contents of a file into a cell.
# - %who: lists all the variables in the current scope.

# %% [markdown]
# ### %run magic command - Calling child notebook from current notebook

# %%
# %run "/Workspace/Users/chen.learning.resources@gmail.com/wd36-local-dbnotebook/CK_4_child_nb"

# %% [markdown]
# ####To run multiple through single cell use dbutils; %run will allow only one

# %%
# %python
dbutils.notebook.run("/Workspace/Users/chen.learning.resources@gmail.com/wd36-local-dbnotebook/CK_4_child_nb", 10)
dbutils.notebook.run("/Workspace/Users/chen.learning.resources@gmail.com/wd36-local-dbnotebook/CK_4_child_nb", 10)


dbutils.fs.ls("dbfs:///")

# %% [markdown]
# ###%fs magic command - To work with datbricks filesystem

# %%
# %fs

# %%
# %fs 
ls

# %%
# %fs ls /

# %%
# %fs ls /Volumes/workspace/default/volumewd36

# %%
dbutils.fs.cp("/Volumes/workspace/default/volumewd36/patients.csv","/Volumes/workspace/default/volume1/patients.csv")

# %%
## https://public.tableau.com/app/sample-data/mobile_os_usage.csv
import requests

data = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
print(data.text)
dbutils.fs.put("/Volumes/workspace/default/volume1/mobile_os_usage.csv", data.text)

# %%
# %fs
ls "/Volumes/workspace/default/volume1"

# %% [markdown]
# ###%sh magic command - To work with local file system

# %%
# %sh
# ls -lrt /
ls -lrt /databricks-datasets/airlines/part-00001 
head -2 /databricks-datasets/airlines/part-00001

# %%
# %fs ls /Volumes/workspace/default/volume1

# %%
# %fs ls "/Volumes/workspace/default/volume1/"

# %%
# %sh
ls -l /Workspace/Users/chen.learning.resources@gmail.com/wd36-local-dbnotebook

# %%
# %sh
ls -l /Volumes/workspace/default/volume1

# %% [markdown]
# ###Note:
# Unity catalog overview demo (will learn later) <br>
# create tables and filew under the volumne (catalog/schema/volumnename/folder/file)

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.volume1;
CREATE VOLUME IF NOT EXISTS workspace.default.volumewd36;
-- After executin go and check in catalog under workspace default

# %% [markdown]
# ###%sql magic command - To work with databases and tables

# %%
# %sql
create table if not exists default.cities(id int,city string);
insert into default.cities values(3,'Mumbai'),(4,'Lucknow');
select * from cities;

# %%
# %sql
insert into default.cities values(1,'Chennai')

# %%
# %sql
select * from cities;

# %%
# %sql
update cities set city='Kolkata' where id=4

# %%
# %sql
select * from cities;

# %%
# %python
df1 = spark.read.csv("/Volumes/workspace/default/volume1/patients.csv", header=True, inferSchema=True)
df1.show()

# %%
# %python
df2 = df1.repartition(4)
df2.show()

# %% [markdown]
# ###%pip -to install python libaries

# %%
# %pip install pypi
